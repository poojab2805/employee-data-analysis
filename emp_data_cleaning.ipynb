# %%
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
df=pd.read_csv("messy_employee_data.csv")

# %%
df
# Out:
#     Employee_ID Employee_Name   Age   Gender       City Department   Salary  \
# 0       EMP0001  Rahul Sharma  28.0     Male     Mumbai      Sales  94163.0
# 1       EMP0002   Priya Patel  41.0   Female       Pune         IT  50939.0
# 2       EMP0003    Amit Kumar  36.0     male      Delhi         HR  73925.0
# 3       EMP0004   Sneha Joshi  32.0   FEMALE  Bangalore  Marketing  67941.0
# 4       EMP0005  Vikram Singh  29.0        M     mumbai      sales  46834.0
# ..          ...           ...   ...      ...        ...        ...      ...
# 195         NaN  Rahul Sharma   NaN        F       PUNE         it      NaN
# 196         NaN   Priya Patel   NaN   female      delhi        H.R      NaN
# 197         NaN    Amit Kumar   NaN    Male   bangalore  marketing      NaN
# 198         NaN   Sneha Joshi   NaN   Female  Hyderabad    Finance      NaN
# 199         NaN  Vikram Singh   NaN      NaN        NaN        NaN      NaN
#
# ...

# %%
df.shape
# Out:
# (200, 15)

# %%
df.head(10)
# Out:
#   Employee_ID   Employee_Name   Age   Gender       City Department    Salary  \
# 0     EMP0001    Rahul Sharma  28.0     Male     Mumbai      Sales   94163.0
# 1     EMP0002     Priya Patel  41.0   Female       Pune         IT   50939.0
# 2     EMP0003      Amit Kumar  36.0     male      Delhi         HR   73925.0
# 3     EMP0004     Sneha Joshi  32.0   FEMALE  Bangalore  Marketing   67941.0
# 4     EMP0005    Vikram Singh  29.0        M     mumbai      sales   46834.0
# 5     EMP0006     Pooja Mehta  42.0        F       PUNE         it   43047.0
# 6     EMP0007  Rohan Kulkarni  28.0   female      delhi        H.R   51105.0
# 7     EMP0008      Neha Verma  40.0    Male   bangalore  marketing  100766.0
# 8     EMP0009     Suresh Nair  44.0   Female  Hyderabad    Finance   40707.0
# 9     EMP0010    Kavita Reddy  32.0      NaN        NaN        NaN   46976.0
#
#    Experience_Years      Education  Performance_Score Joining_Date  \
# ...

# %%
df.tail(10)
# Out:
#     Employee_ID Employee_Name  Age   Gender       City Department  Salary  \
# 190         NaN  rahul sharma  NaN     Male     Mumbai      Sales     NaN
# 191         NaN   PRIYA PATEL  NaN   Female       Pune         IT     NaN
# 192         NaN   Amit Kumar   NaN     male      Delhi         HR     NaN
# 193         NaN  Sneha  Joshi  NaN   FEMALE  Bangalore  Marketing     NaN
# 194         NaN           NaN  NaN        M     mumbai      sales     NaN
# 195         NaN  Rahul Sharma  NaN        F       PUNE         it     NaN
# 196         NaN   Priya Patel  NaN   female      delhi        H.R     NaN
# 197         NaN    Amit Kumar  NaN    Male   bangalore  marketing     NaN
# 198         NaN   Sneha Joshi  NaN   Female  Hyderabad    Finance     NaN
# 199         NaN  Vikram Singh  NaN      NaN        NaN        NaN     NaN
#
#      Experience_Years      Education  Performance_Score Joining_Date  \
# 190               NaN           12th                NaN   15/03/2020
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        185 non-null    object
#  1   Employee_Name      187 non-null    object
#  2   Age                166 non-null    float64
#  3   Gender             180 non-null    object
#  4   City               180 non-null    object
#  5   Department         180 non-null    object
#  6   Salary             165 non-null    float64
#  7   Experience_Years   169 non-null    float64
#  8   Education          175 non-null    object
#  9   Performance_Score  170 non-null    float64
#  10  Joining_Date       160 non-null    object
#  11  Phone_Number       175 non-null    object
#  12  Email              175 non-null    object
#  13  Monthly_Bonus      170 non-null    float64
#  14  Salary_Text        165 non-null    object
# dtypes: float64(5), object(10)
# ...

# %%
df.isnull()
# Out:
#      Employee_ID  Employee_Name    Age  Gender   City  Department  Salary  \
# 0          False          False  False   False  False       False   False
# 1          False          False  False   False  False       False   False
# 2          False          False  False   False  False       False   False
# 3          False          False  False   False  False       False   False
# 4          False          False  False   False  False       False   False
# ..           ...            ...    ...     ...    ...         ...     ...
# 195         True          False   True   False  False       False    True
# 196         True          False   True   False  False       False    True
# 197         True          False   True   False  False       False    True
# 198         True          False   True   False  False       False    True
# 199         True          False   True    True   True        True    True
#
#      Experience_Years  Education  Performance_Score  Joining_Date  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID          15
# Employee_Name        13
# Age                  34
# Gender               20
# City                 20
# Department           20
# Salary               35
# Experience_Years     31
# Education            25
# Performance_Score    30
# Joining_Date         40
# Phone_Number         25
# Email                25
# Monthly_Bonus        30
# Salary_Text          35
# dtype: int64

# %%
df.describe()
# Out:
#               Age         Salary  Experience_Years  Performance_Score  \
# count  166.000000     165.000000        169.000000         170.000000
# mean    39.433735   89418.448485          9.798817           5.535294
# std     77.008570   81011.105842          9.912462           7.812253
# min     -5.000000   -5000.000000         -5.000000          -1.000000
# 25%     27.000000   50939.000000          3.000000           3.000000
# 50%     32.500000   85713.000000          9.000000           5.000000
# 75%     38.000000  118264.000000         15.000000           7.000000
# max    999.000000  999999.000000        100.000000         100.000000
#
#        Monthly_Bonus
# count     170.000000
# mean    10762.111765
# std      5264.667796
# min      1009.000000
# 25%      6260.000000
# 50%     10885.500000
# 75%     15164.500000
# max     19977.000000

# %%
df.dtypes
# Out:
# Employee_ID           object
# Employee_Name         object
# Age                  float64
# Gender                object
# City                  object
# Department            object
# Salary               float64
# Experience_Years     float64
# Education             object
# Performance_Score    float64
# Joining_Date          object
# Phone_Number          object
# Email                 object
# Monthly_Bonus        float64
# Salary_Text           object
# dtype: object

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Employee_ID           7.5
# Employee_Name         6.5
# Age                  17.0
# Gender               10.0
# City                 10.0
# Department           10.0
# Salary               17.5
# Experience_Years     15.5
# Education            12.5
# Performance_Score    15.0
# Joining_Date         20.0
# Phone_Number         12.5
# Email                12.5
# Monthly_Bonus        15.0
# Salary_Text          17.5
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Employee_Name, Age, Gender, City, Department, Salary, Experience_Years, Education, Performance_Score, Joining_Date, Phone_Number, Email, Monthly_Bonus, Salary_Text]
# Index: []

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Age', 'Gender', 'City', 'Department',
#        'Salary', 'Experience_Years', 'Education', 'Performance_Score',
#        'Joining_Date', 'Phone_Number', 'Email', 'Monthly_Bonus',
#        'Salary_Text'],
#       dtype='object')

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'male', 'FEMALE', 'M', 'F', 'female', 'Male ',
#        ' Female', nan], dtype=object)

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Post Graduate', 'graduate', 'POST GRADUATE',
#        'Diploma', 'diploma', '12th', nan], dtype=object)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'IT', 'HR', 'Marketing', 'sales', 'it', 'H.R',
#        'marketing', 'Finance', nan], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Delhi', 'Bangalore', 'mumbai', 'PUNE', 'delhi',
#        'bangalore', 'Hyderabad', nan], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       20
# Female     20
# male       20
# FEMALE     20
# M          20
# F          20
# female     20
# Male       20
#  Female    20
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai       20
# Pune         20
# Delhi        20
# Bangalore    20
# mumbai       20
# PUNE         20
# delhi        20
# bangalore    20
# Hyderabad    20
# Name: count, dtype: int64

# %%
df=df.drop_duplicates(subset='Employee_ID',keep='first')

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#     Employee_ID Employee_Name   Age   Gender       City Department   Salary  \
# 0       EMP0001  Rahul Sharma  28.0     Male     Mumbai      Sales  94163.0
# 1       EMP0002   Priya Patel  41.0   Female       Pune         IT  50939.0
# 2       EMP0003    Amit Kumar  36.0     male      Delhi         HR  73925.0
# 3       EMP0004   Sneha Joshi  32.0   FEMALE  Bangalore  Marketing  67941.0
# 4       EMP0005  Vikram Singh  29.0        M     mumbai      sales  46834.0
# ..          ...           ...   ...      ...        ...        ...      ...
# 166     EMP0167   Priya Patel   NaN   female      delhi        H.R      NaN
# 167     EMP0168    Amit Kumar   NaN    Male   bangalore  marketing      NaN
# 168     EMP0169   Sneha Joshi   NaN   Female  Hyderabad    Finance      NaN
# 169     EMP0170  Vikram Singh   NaN      NaN        NaN        NaN      NaN
# 170         NaN   Pooja Mehta   NaN        F       PUNE         it      NaN
#
# ...

# %%
df['Employee_Name']=df['Employee_Name'].str.strip()

# %%
df['Employee_Name']
# Out:
# 0      Rahul Sharma
# 1       Priya Patel
# 2        Amit Kumar
# 3       Sneha Joshi
# 4      Vikram Singh
#            ...
# 166     Priya Patel
# 167      Amit Kumar
# 168     Sneha Joshi
# 169    Vikram Singh
# 170     Pooja Mehta
# Name: Employee_Name, Length: 171, dtype: object

# %%
df.loc[1,'Employee_Name'] = ' Priya   Patel          '

# %%
df['Employee_Name']
# Out:
# 0                  Rahul Sharma
# 1       Priya   Patel
# 2                    Amit Kumar
# 3                   Sneha Joshi
# 4                  Vikram Singh
#                  ...
# 166                 Priya Patel
# 167                  Amit Kumar
# 168                 Sneha Joshi
# 169                Vikram Singh
# 170                 Pooja Mehta
# Name: Employee_Name, Length: 171, dtype: object

# %%
df['Employee_Name']=df['Employee_Name'].str.strip()

# %%
df['Gender'].str.strip()
df['City'].str.strip()
df['Education'].str.strip()
df['Department'].str.strip()
# Out:
# 0          Sales
# 1             IT
# 2             HR
# 3      Marketing
# 4          sales
#          ...
# 166          H.R
# 167    marketing
# 168      Finance
# 169          NaN
# 170           it
# Name: Department, Length: 171, dtype: object

# %%
df['Employee_Name']=df['Employee_Name'].str.replace(r'\s+',' ',regex=True)

# %%
df['Employee_Name']
# Out:
# 0      Rahul Sharma
# 1       Priya Patel
# 2        Amit Kumar
# 3       Sneha Joshi
# 4      Vikram Singh
#            ...
# 166     Priya Patel
# 167      Amit Kumar
# 168     Sneha Joshi
# 169    Vikram Singh
# 170     Pooja Mehta
# Name: Employee_Name, Length: 171, dtype: object

# %%
df['Gender']=df['Gender'].str.strip().str.title()

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4           M
#         ...
# 166    Female
# 167      Male
# 168    Female
# 169       NaN
# 170         F
# Name: Gender, Length: 171, dtype: object

# %%
df['Gender']=df['Gender'].replace(
    {
        'F':'Female',
        'M':'Male'
    }
)

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 166    Female
# 167      Male
# 168    Female
# 169       NaN
# 170    Female
# Name: Gender, Length: 171, dtype: object

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(17)

# %%
df['City']=df['City'].str.title()

# %%
df['City']
# Out:
# 0         Mumbai
# 1           Pune
# 2          Delhi
# 3      Bangalore
# 4         Mumbai
#          ...
# 166        Delhi
# 167    Bangalore
# 168    Hyderabad
# 169          NaN
# 170         Pune
# Name: City, Length: 171, dtype: object

# %%
df['City'].value_counts()
# Out:
# City
# Pune         35
# Mumbai       34
# Delhi        34
# Bangalore    34
# Hyderabad    17
# Name: count, dtype: int64

# %%
df['Department']=df['Department'].str.title()

# %%
df['Department'].value_counts()
# Out:
# Department
# It           35
# Sales        34
# Marketing    34
# Hr           17
# H.R          17
# Finance      17
# Name: count, dtype: int64

# %%
df['Department']=df['Department'].replace(
    {
        'Hr':'HR',
        'H.R':'HR',
        'It':'IT'
    }
)

# %%
df['Department']
# Out:
# 0          Sales
# 1             IT
# 2             HR
# 3      Marketing
# 4          Sales
#          ...
# 166           HR
# 167    Marketing
# 168      Finance
# 169          NaN
# 170           IT
# Name: Department, Length: 171, dtype: object

# %%
df['Department'].value_counts()
# Out:
# Department
# IT           35
# Sales        34
# HR           34
# Marketing    34
# Finance      17
# Name: count, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Education
# Post Graduate    23
# Graduate         22
# graduate         21
# POST GRADUATE    21
# Diploma          21
# diploma          21
# 12th             21
# Name: count, dtype: int64

# %%
df['Education']=df['Education'].str.title()

# %%
df['Education'].value_counts()
# Out:
# Education
# Post Graduate    44
# Graduate         43
# Diploma          42
# 12Th             21
# Name: count, dtype: int64

# %%
df['Age']=df['Age'].astype(float)
df['Age']=np.where(((df['Age'] < 18) | (df['Age'] > 65)),np.nan,df['Age'])

# %%
df['Age']
# Out:
# 0      28.0
# 1      41.0
# 2      36.0
# 3      32.0
# 4      29.0
#        ...
# 166     NaN
# 167     NaN
# 168     NaN
# 169     NaN
# 170     NaN
# Name: Age, Length: 171, dtype: float64

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(11)

# %%
df['Salary']=df['Salary'].astype(float)
df['Salary']=np.where(((df['Salary']<0)|(df['Salary']>50000)),np.nan,df['Salary'])

# %%
df['Salary']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4      46834.0
#         ...
# 166        NaN
# 167        NaN
# 168        NaN
# 169        NaN
# 170        NaN
# Name: Salary, Length: 171, dtype: float64

# %%
(df['Salary'].isnull().sum()/len(df))*100
# Out:
# np.float64(78.94736842105263)

# %%
df['Experience_Years']=df['Experience_Years'].astype(float)
df['Experience_Years']=np.where(((df['Experience_Years']<0)|(df['Experience_Years']>40)),np.nan,df['Experience_Years'])

# %%
df['Experience_Years']
# Out:
# 0      16.0
# 1       7.0
# 2       3.0
# 3       5.0
# 4       7.0
#        ...
# 166     NaN
# 167     NaN
# 168     NaN
# 169     NaN
# 170     NaN
# Name: Experience_Years, Length: 171, dtype: float64

# %%
(df['Experience_Years'].isnull().sum()/len(df))*100
# Out:
# np.float64(3.508771929824561)

# %%
df['Performance_Score']=df['Performance_Score'].astype(float)
df['Performance_Score']=np.where(((df['Performance_Score']<0)|(df['Performance_Score']>10)),np.nan,df['Performance_Score'])

# %%
(df['Performance_Score'].isnull().sum()/len(df))*100
# Out:
# np.float64(2.923976608187134)

# %%
print(df[['Salary','Age','Experience_Years','Performance_Score']].isnull().sum())
# Out:
# Salary               135
# Age                   11
# Experience_Years       6
# Performance_Score      5
# dtype: int64

# %%
#filling categorical values by median of the same column
df['Age']=df['Age'].fillna(df['Age'].median())
df['Experience_Years']=df['Experience_Years'].fillna(df['Experience_Years'].median())
df['Salary']=df['Salary'].fillna(df['Salary'].median())
df['Performance_Score']=df['Performance_Score'].fillna(df['Performance_Score'].median())

# %%
print(df[['Salary','Age','Experience_Years','Performance_Score']].isnull().sum())
# Out:
# Salary               0
# Age                  0
# Experience_Years     0
# Performance_Score    0
# dtype: int64

# %%
df['Salary']
# Out:
# 0      36797.0
# 1      36797.0
# 2      36797.0
# 3      36797.0
# 4      46834.0
#         ...
# 166    36797.0
# 167    36797.0
# 168    36797.0
# 169    36797.0
# 170    36797.0
# Name: Salary, Length: 171, dtype: float64

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Education']=df['Education'].fillna(df['Education'].mode()[0])
df['City']=df['City'].fillna(df['City'].mode()[0])
df['Department']=df['Department'].fillna(df['Department'].mode()[0])

# %%
df[['Gender','City','Department',"Education"]].isnull().sum()
# Out:
# Gender        0
# City          0
# Department    0
# Education     0
# dtype: int64

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 166    Female
# 167      Male
# 168    Female
# 169    Female
# 170    Female
# Name: Gender, Length: 171, dtype: object

# %%
df=df.dropna(subset=['Employee_Name','Employee_ID'])

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#     Employee_ID Employee_Name   Age  Gender       City Department   Salary  \
# 0       EMP0001  Rahul Sharma  28.0    Male     Mumbai      Sales  36797.0
# 1       EMP0002   Priya Patel  41.0  Female       Pune         IT  36797.0
# 2       EMP0003    Amit Kumar  36.0    Male      Delhi         HR  36797.0
# 3       EMP0004   Sneha Joshi  32.0  Female  Bangalore  Marketing  36797.0
# 4       EMP0005  Vikram Singh  29.0    Male     Mumbai      Sales  46834.0
# ..          ...           ...   ...     ...        ...        ...      ...
# 154     EMP0166  Rahul Sharma  32.5  Female       Pune         IT  36797.0
# 155     EMP0167   Priya Patel  32.5  Female      Delhi         HR  36797.0
# 156     EMP0168    Amit Kumar  32.5    Male  Bangalore  Marketing  36797.0
# 157     EMP0169   Sneha Joshi  32.5  Female  Hyderabad    Finance  36797.0
# 158     EMP0170  Vikram Singh  32.5  Female       Pune         IT  36797.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Employee_Name         0
# Age                   0
# Gender                0
# City                  0
# Department            0
# Salary                0
# Experience_Years      0
# Education             0
# Performance_Score     0
# Joining_Date         29
# Phone_Number         20
# Email                19
# Monthly_Bonus         0
# Salary_Text           5
# dtype: int64

# %%
df
# Out:
#     Employee_ID Employee_Name   Age  Gender       City Department   Salary  \
# 0       EMP0001  Rahul Sharma  28.0    Male     Mumbai      Sales  36797.0
# 1       EMP0002   Priya Patel  41.0  Female       Pune         IT  36797.0
# 2       EMP0003    Amit Kumar  36.0    Male      Delhi         HR  36797.0
# 3       EMP0004   Sneha Joshi  32.0  Female  Bangalore  Marketing  36797.0
# 4       EMP0005  Vikram Singh  29.0    Male     Mumbai      Sales  46834.0
# ..          ...           ...   ...     ...        ...        ...      ...
# 154     EMP0166  Rahul Sharma  32.5  Female       Pune         IT  36797.0
# 155     EMP0167   Priya Patel  32.5  Female      Delhi         HR  36797.0
# 156     EMP0168    Amit Kumar  32.5    Male  Bangalore  Marketing  36797.0
# 157     EMP0169   Sneha Joshi  32.5  Female  Hyderabad    Finance  36797.0
# 158     EMP0170  Vikram Singh  32.5  Female       Pune         IT  36797.0
#
# ...

# %%
df['Salary']=df['Salary'].astype(int)
df['Age']=df['Age'].astype(int)
df['Performance_Score']=df['Performance_Score'].astype(int)
df['Experience_Years']=df['Experience_Years'].astype(int)

# %%
df['valid_phone']=df['Phone_Number'].apply(
    lambda x:'Valid' if pd.notnull(x) and str(x).isdigit() and len(str(x)) == 10 else 'Invalid'
)

# %%
df['valid_phone']
# Out:
# 0        Valid
# 1        Valid
# 2      Invalid
# 3      Invalid
# 4      Invalid
#         ...
# 154    Invalid
# 155    Invalid
# 156    Invalid
# 157      Valid
# 158      Valid
# Name: valid_phone, Length: 159, dtype: object

# %%
df
# Out:
#     Employee_ID Employee_Name  Age  Gender       City Department  Salary  \
# 0       EMP0001  Rahul Sharma   28    Male     Mumbai      Sales   36797
# 1       EMP0002   Priya Patel   41  Female       Pune         IT   36797
# 2       EMP0003    Amit Kumar   36    Male      Delhi         HR   36797
# 3       EMP0004   Sneha Joshi   32  Female  Bangalore  Marketing   36797
# 4       EMP0005  Vikram Singh   29    Male     Mumbai      Sales   46834
# ..          ...           ...  ...     ...        ...        ...     ...
# 154     EMP0166  Rahul Sharma   32  Female       Pune         IT   36797
# 155     EMP0167   Priya Patel   32  Female      Delhi         HR   36797
# 156     EMP0168    Amit Kumar   32    Male  Bangalore  Marketing   36797
# 157     EMP0169   Sneha Joshi   32  Female  Hyderabad    Finance   36797
# 158     EMP0170  Vikram Singh   32  Female       Pune         IT   36797
#
#      Experience_Years      Education  Performance_Score    Phone_Number  \
# ...

# %%
import re
def validate_email(email):
    if pd.isnull(email):
        return 'missing'
    pattern = r'^[\w\.-]+@[\w\.-]+\.\w+$'
    return 'Valid' if re.match(pattern,str(email)) else 'Invalid'

df['Valid_Email']=df['Email'].apply(validate_email)

# %%
df['Valid_Email'].value_counts()
# Out:
# Valid_Email
# Valid      81
# Invalid    59
# missing    19
# Name: count, dtype: int64

# %%
conditions =[
    df['Salary']<40000,(df['Salary']>40000) & (df['Salary']<80000),(df['Salary']>80000) & (df['Salary']< 120000),df['Salary']>120000
]
choices=['junior','mid level','senior','lead']
df['Salary_Grade']=np.select(conditions,choices,default='Unknown')

# %%
df['Salary_Grade']
# Out:
# 0         junior
# 1         junior
# 2         junior
# 3         junior
# 4      mid level
#          ...
# 154       junior
# 155       junior
# 156       junior
# 157       junior
# 158       junior
# Name: Salary_Grade, Length: 159, dtype: object

# %%
df['Salary'].describe()
# Out:
# count      159.000000
# mean     36658.157233
# std       4428.222022
# min          0.000000
# 25%      36797.000000
# 50%      36797.000000
# 75%      36797.000000
# max      48776.000000
# Name: Salary, dtype: float64

# %%
df['Total_compensation']=df['Salary']+df['Monthly_Bonus']

# %%
df['Total_compensation']
# Out:
# 0      43117.0
# 1      51013.0
# 2      40576.0
# 3      55105.0
# 4      49415.0
#         ...
# 154    56157.0
# 155    55477.0
# 156    44026.0
# 157    54306.0
# 158    52944.0
# Name: Total_compensation, Length: 159, dtype: float64

# %%
df['Performance_category']=pd.cut(df['Performance_Score'],bins=[0,3,6,8,10],labels=['Poor','Average','Good','Excellent'])

# %%
df['Performance_category'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Performance_category'].value_counts()
# Out:
# Performance_category
# Average      53
# Poor         51
# Good         34
# Excellent    20
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (159, 18)

# %%
df.dtypes
# Out:
# Employee_ID               object
# Employee_Name             object
# Age                        int64
# Gender                    object
# City                      object
# Department                object
# Salary                     int64
# Experience_Years           int64
# Education                 object
# Performance_Score          int64
# Phone_Number              object
# Email                     object
# Monthly_Bonus            float64
# valid_phone               object
# Valid_Email               object
# Salary_Grade              object
# Total_compensation       float64
# Performance_category    category
# dtype: object

# %%
df['Total_compensation']=df['Total_compensation'].astype(int)
df['Monthly_Bonus']=df['Monthly_Bonus'].astype(int)

# %%
df.dtypes
# Out:
# Employee_ID               object
# Employee_Name             object
# Age                        int64
# Gender                    object
# City                      object
# Department                object
# Salary                     int64
# Experience_Years           int64
# Education                 object
# Performance_Score          int64
# Phone_Number              object
# Email                     object
# Monthly_Bonus              int64
# valid_phone               object
# Valid_Email               object
# Salary_Grade              object
# Total_compensation         int64
# Performance_category    category
# dtype: object

# %%
df.isnull().sum()
# Out:
# Employee_ID              0
# Employee_Name            0
# Age                      0
# Gender                   0
# City                     0
# Department               0
# Salary                   0
# Experience_Years         0
# Education                0
# Performance_Score        0
# Phone_Number            20
# Email                   19
# Monthly_Bonus            0
# valid_phone              0
# Valid_Email              0
# Salary_Grade             0
# Total_compensation       0
# Performance_category     1
# dtype: int64

# %%
df.to_csv('Cleaned_Employee_Data.csv')
